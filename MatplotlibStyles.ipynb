# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data1 = np.linspace(0,10,20)

# %%
data1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
data2 = data1 ** 2

# %%
data2
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
plt.subplots()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
my_fig, my_axes = plt.subplots()
my_axes.plot(data1, data2, color="#000000",alpha=0.3)  # alpha--> saydamlık
my_axes.plot(data2, data1, color="#C96F23")
plt.show()

# %%
type(my_fig)
# Out:
# matplotlib.figure.Figure

# %%
type(my_axes)
# Out:
# matplotlib.axes._axes.Axes

# %%
(new_fig, new_axes) = plt.subplots()
new_axes.plot(data1, data1 + 2, color="blue", linewidth = 5.0) #linewidth --> kalınlık
new_axes.plot(data1, data1 + 3, color ="yellow", linewidth = 1.0)

new_axes.plot(data1, data1 + 4, color = "#C96F23", linestyle = "-.")
new_axes.plot(data1, data1 + 5, color = "#C96F23", linestyle = ":")
new_axes.plot(data1, data1 + 6, color = "#C96F23", linestyle = "--")

new_axes.plot(data1, data1 + 7, color = "#000000", linestyle = "--", marker = "o",markersize = 8, markerfacecolor="red")
new_axes.plot(data1, data1 + 8, color = "#000000", linestyle = "--", marker = "+",markersize = 4)

# %%
plt.show()

# %%
# scatter plot

# %%
plt.scatter(data1,data2)

# %%
plt.show()

# %%
#histogram

# %%
new_arr = np.random.randint(0,100,50)

# %%
new_arr
# Out:
# array([82,  4, 49, 17, 12, 62, 82, 56, 51, 88, 22, 80, 67, 53, 73, 18, 18,
#        76, 46, 86, 61, 49, 90, 96, 41, 41, 12, 74, 76, 80, 56, 45, 79, 96,
#        44, 64,  1,  3, 31, 39, 41, 45, 23, 99, 45, 41, 21, 24, 19, 72])

# %%
plt.hist(new_arr)
# Out:
# (array([ 3.,  6.,  4.,  2., 11.,  4.,  4.,  6.,  6.,  4.]),
#  array([ 1. , 10.8, 20.6, 30.4, 40.2, 50. , 59.8, 69.6, 79.4, 89.2, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.show()

# %%
# box plot

# %%
plt.boxplot(new_arr)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x296f4cf0ec0>,
#   <matplotlib.lines.Line2D at 0x296f4cf1190>],
#  'caps': [<matplotlib.lines.Line2D at 0x296f4cf1490>,
#   <matplotlib.lines.Line2D at 0x296f4cf1760>],
#  'boxes': [<matplotlib.lines.Line2D at 0x296f4cf0c80>],
#  'medians': [<matplotlib.lines.Line2D at 0x296f4cf1a30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x296f4cf1cd0>],
#  'means': []}

# %%
plt.show()

# %%
# https://www.geeksforgeeks.org/box-plot/

# %%
# https://en.wikipedia.org/wiki/Box_plot
